# %%
# Dependencies
import pandas as pd
from datetime import date
import sqlite3
import csv
import matplotlib.pyplot as plt

import requests
from pprint import pprint
from config import api_key

url = "https://data.lacity.org/resource/7fvc-faax.json?$order="

# %%
# Search for crimes in the Rampart area

# area_name = "Rampart"
order_by = "date_occ%20DESC"

# %%
# Build query URL
query_url = url + order_by
# query_url = url + "&area_name=" + area_name
# + "api-key=" + api_key + "&?area_name=" + area_name

# %%
# Request articles
incidents = requests.get(query_url).json()

# The "response" property in incidents contains the actual crime incidents
# list comprehension.
incidents_list = [response for response in incidents]
pprint(incidents_list)
# Out:
# [{'area_id': '06',
#   'area_name': 'Hollywood',
#   'crm_cd': '330',
#   'crm_cd_1': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180623987',
#   'location': '1700 N  CAHUENGA                     BL',
#   'location_1': {'coordinates': [-118.3295, 34.1016], 'type': 'Point'},
#   'mocodes': '1307 0344 1609 0329',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'rpt_dist_no': '0636',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0030',
#   'vict_age': '22',
#   'vict_descent': 'O',
#   'vict_sex': 'M'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '626',
#   'crm_cd_1': '626',
#   'crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180518688',
#   'location': '3600    STEPHEN M WHITE              DR',
#   'location_1': {'coordinates': [-118.2879, 33.7115], 'type': 'Point'},
#   'mocodes': '0432 0444 0913 1241 1243 1813 2000',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'rpt_dist_no': '0589',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0140',
#   'vict_age': '39',
#   'vict_descent': 'H',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '06',
#   'area_name': 'Hollywood',
#   'crm_cd': '740',
#   'crm_cd_1': '740',
#   'crm_cd_desc': 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180623984',
#   'location': '800 N  KINGSLEY                     DR',
#   'location_1': {'coordinates': [-118.3028, 34.0849], 'type': 'Point'},
#   'mocodes': '1822 0329',
#   'premis_cd': '122',
#   'premis_desc': 'VEHICLE, PASSENGER/TRUCK',
#   'rpt_dist_no': '0678',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0700',
#   'vict_age': '33',
#   'vict_descent': 'B',
#   'vict_sex': 'M'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180518700',
#   'location': '18400 S  VERMONT                      AV',
#   'location_1': {'coordinates': [-118.2905, 33.8637], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0501',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1130',
#   'vict_age': '17'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180128324',
#   'location': '400 S  HEWITT                       ST',
#   'location_1': {'coordinates': [-118.2354, 34.0436], 'type': 'Point'},
#   'mocodes': '0305 0416',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '0159',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0100',
#   'vict_age': '51',
#   'vict_descent': 'W',
#   'vict_sex': 'M',
#   'weapon_desc': 'UNKNOWN WEAPON/OTHER WEAPON',
#   'weapon_used_cd': '500'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '440',
#   'crm_cd_1': '440',
#   'crm_cd_desc': 'THEFT PLAIN - PETTY ($950 & UNDER)',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180128339',
#   'location': '400 S  SAN PEDRO                    ST',
#   'location_1': {'coordinates': [-118.243, 34.0458], 'type': 'Point'},
#   'mocodes': '0344',
#   'premis_cd': '517',
#   'premis_desc': 'MISSIONS/SHELTERS',
#   'rpt_dist_no': '0148',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1055',
#   'vict_age': '52',
#   'vict_descent': 'B',
#   'vict_sex': 'F'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '740',
#   'crm_cd_1': '740',
#   'crm_cd_desc': 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181018741',
#   'location': '15700    VENTURA                      BL',
#   'location_1': {'coordinates': [-118.4749, 34.1552], 'type': 'Point'},
#   'mocodes': '0329',
#   'premis_cd': '210',
#   'premis_desc': 'RESTAURANT/FAST FOOD',
#   'rpt_dist_no': '1089',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0205',
#   'vict_descent': 'W',
#   'vict_sex': 'M'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'cross_street': 'HATTERAS',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180920817',
#   'location': 'SEPULVEDA',
#   'location_1': {'coordinates': [-118.4662, 34.1758], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0941',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0700',
#   'vict_age': '17'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181018725',
#   'location': '8000    CHIMINEAS                    AV',
#   'location_1': {'coordinates': [-118.5287, 34.2165], 'type': 'Point'},
#   'mocodes': '0400 0444',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '1004',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2325',
#   'vict_age': '63',
#   'vict_descent': 'H',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181018726',
#   'location': '8000    CHIMINEAS                    AV',
#   'location_1': {'coordinates': [-118.5287, 34.2165], 'type': 'Point'},
#   'mocodes': '0400 0444',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '1004',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2325',
#   'vict_age': '50',
#   'vict_descent': 'H',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '18',
#   'area_name': 'Southeast',
#   'crm_cd': '350',
#   'crm_cd_1': '350',
#   'crm_cd_desc': 'THEFT, PERSON',
#   'cross_street': 'CENTURY                      BL',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181822539',
#   'location': 'AVALON                       BL',
#   'location_1': {'coordinates': [-118.2652, 33.9456], 'type': 'Point'},
#   'mocodes': '1259 0216 0346 0344',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '1823',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0850',
#   'vict_age': '14',
#   'vict_descent': 'B',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '17',
#   'area_name': 'Devonshire',
#   'crm_cd': '740',
#   'crm_cd_1': '740',
#   'crm_cd_desc': 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181719011',
#   'location': '14300    SAN FERNANDO                 RD',
#   'location_1': {'coordinates': [-118.4907, 34.3152], 'type': 'Point'},
#   'mocodes': '0329',
#   'premis_cd': '203',
#   'premis_desc': 'OTHER BUSINESS',
#   'rpt_dist_no': '1708',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0130',
#   'vict_age': '33',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '13',
#   'area_name': 'Newton',
#   'crm_cd': '626',
#   'crm_cd_1': '626',
#   'crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181322928',
#   'location': '200 E  30TH                         ST',
#   'location_1': {'coordinates': [-118.2696, 34.0213], 'type': 'Point'},
#   'mocodes': '2000 0400 0429',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '1331',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0530',
#   'vict_age': '36',
#   'vict_descent': 'H',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '16',
#   'area_name': 'Foothill',
#   'crm_cd': '900',
#   'crm_cd_1': '900',
#   'crm_cd_desc': 'VIOLATION OF COURT ORDER',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181616644',
#   'location': '12400    OSBORNE                      ST',
#   'location_1': {'coordinates': [-118.4094, 34.2626], 'type': 'Point'},
#   'mocodes': '0603',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'rpt_dist_no': '1645',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1115',
#   'vict_age': '50',
#   'vict_descent': 'B',
#   'vict_sex': 'F'},
#  {'area_id': '13',
#   'area_name': 'Newton',
#   'crm_cd': '648',
#   'crm_cd_1': '648',
#   'crm_cd_desc': 'ARSON',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181322936',
#   'location': '5100    AVALON                       BL',
#   'location_1': {'coordinates': [-118.2697, 33.9981], 'type': 'Point'},
#   'mocodes': '1501 1300 1420',
#   'premis_cd': '122',
#   'premis_desc': 'VEHICLE, PASSENGER/TRUCK',
#   'rpt_dist_no': '1362',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0001',
#   'vict_age': '34',
#   'vict_descent': 'B',
#   'vict_sex': 'M',
#   'weapon_desc': 'FIRE',
#   'weapon_used_cd': '506'},
#  {'area_id': '16',
#   'area_name': 'Foothill',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181616633',
#   'location': '12200    FOOTHILL                     BL',
#   'location_1': {'coordinates': [-118.4018, 34.2809], 'type': 'Point'},
#   'mocodes': '0417 0419 0429',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'rpt_dist_no': '1602',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0700',
#   'vict_age': '29',
#   'vict_descent': 'H',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '17',
#   'area_name': 'Devonshire',
#   'crm_cd': '928',
#   'crm_cd_1': '928',
#   'crm_cd_desc': 'THREATENING PHONE CALLS/LETTERS',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181719021',
#   'location': '17000    ROSCOE                       BL',
#   'location_1': {'coordinates': [-118.5151, 34.2248], 'type': 'Point'},
#   'mocodes': '1501',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '1795',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1035',
#   'vict_age': '49',
#   'vict_descent': 'O',
#   'vict_sex': 'M',
#   'weapon_desc': 'VERBAL THREAT',
#   'weapon_used_cd': '511'},
#  {'area_id': '15',
#   'area_name': 'N Hollywood',
#   'crm_cd': '626',
#   'crm_cd_1': '626',
#   'crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181501307',
#   'location': '12500    OXNARD                       ST',
#   'location_1': {'coordinates': [-118.4052, 34.1794], 'type': 'Point'},
#   'mocodes': '2000 0448',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'rpt_dist_no': '1531',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0900',
#   'vict_age': '23',
#   'vict_descent': 'H',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '13',
#   'area_name': 'Newton',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181322927',
#   'location': '200 E  43RD                         PL',
#   'location_1': {'coordinates': [-118.272, 34.0048], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '1352',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0010',
#   'vict_age': '17'},
#  {'area_id': '12',
#   'area_name': '77th Street',
#   'crm_cd': '236',
#   'crm_cd_1': '236',
#   'crm_cd_desc': 'INTIMATE PARTNER - AGGRAVATED ASSAULT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181227296',
#   'location': '4400 S  NORMANDIE                    AV',
#   'location_1': {'coordinates': [-118.3002, 34.0037], 'type': 'Point'},
#   'mocodes': '2000 0344 0413 0417 1814',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '1204',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1215',
#   'vict_age': '23',
#   'vict_descent': 'B',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '17',
#   'area_name': 'Devonshire',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181719009',
#   'location': '18000    SCHOENBORN                   ST',
#   'location_1': {'coordinates': [-118.5252, 34.2218], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '1795',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1130',
#   'vict_age': '17'},
#  {'area_id': '17',
#   'area_name': 'Devonshire',
#   'crm_cd': '341',
#   'crm_cd_1': '341',
#   'crm_cd_desc': 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181719015',
#   'location': '9500    RESEDA                       BL',
#   'location_1': {'coordinates': [-118.5361, 34.2428], 'type': 'Point'},
#   'mocodes': '0603 0344',
#   'premis_cd': '203',
#   'premis_desc': 'OTHER BUSINESS',
#   'rpt_dist_no': '1767',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0827',
#   'vict_age': '44',
#   'vict_descent': 'W',
#   'vict_sex': 'F'},
#  {'area_id': '16',
#   'area_name': 'Foothill',
#   'crm_cd': '900',
#   'crm_cd_1': '900',
#   'crm_cd_desc': 'VIOLATION OF COURT ORDER',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181616627',
#   'location': '11200    NORRIS                       AV',
#   'location_1': {'coordinates': [-118.4194, 34.2734], 'type': 'Point'},
#   'mocodes': '2004 0913',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '1612',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0335',
#   'vict_age': '50',
#   'vict_descent': 'B',
#   'vict_sex': 'F'},
#  {'area_id': '12',
#   'area_name': '77th Street',
#   'crm_cd': '230',
#   'crm_cd_1': '230',
#   'crm_cd_desc': 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#   'cross_street': 'VERMONT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181227298',
#   'location': '59TH                         PL',
#   'location_1': {'coordinates': [-118.2915, 33.9869], 'type': 'Point'},
#   'mocodes': '1309 1814 2000 0416',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '1239',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0200',
#   'vict_age': '50',
#   'vict_descent': 'B',
#   'vict_sex': 'M',
#   'weapon_desc': 'VEHICLE',
#   'weapon_used_cd': '307'},
#  {'area_id': '16',
#   'area_name': 'Foothill',
#   'crm_cd': '888',
#   'crm_cd_1': '888',
#   'crm_cd_desc': 'TRESPASSING',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181616637',
#   'location': '10000    LAUREL CANYON                BL',
#   'location_1': {'coordinates': [-118.4249, 34.252], 'type': 'Point'},
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'rpt_dist_no': '1641',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0500',
#   'vict_age': '62',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '13',
#   'area_name': 'Newton',
#   'crm_cd': '230',
#   'crm_cd_1': '230',
#   'crm_cd_desc': 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181322911',
#   'location': '400 E  49TH                         ST',
#   'location_1': {'coordinates': [-118.2696, 33.9988], 'type': 'Point'},
#   'mocodes': '0416 0334',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '1362',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2100',
#   'vict_age': '24',
#   'vict_descent': 'H',
#   'vict_sex': 'M',
#   'weapon_desc': 'UNKNOWN WEAPON/OTHER WEAPON',
#   'weapon_used_cd': '500'},
#  {'area_id': '20',
#   'area_name': 'Olympic',
#   'crm_cd': '440',
#   'crm_cd_1': '440',
#   'crm_cd_desc': 'THEFT PLAIN - PETTY ($950 & UNDER)',
#   'date_occ': '2018-11-17T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '182020654',
#   'location': '1700 S  WESTERN                      AV',
#   'location_1': {'coordinates': [-118.309, 34.0427], 'type': 'Point'},
#   'mocodes': '0344 0352 1221 2014',
#   'premis_cd': '210',
#   'premis_desc': 'RESTAURANT/FAST FOOD',
#   'rpt_dist_no': '2083',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0410',
#   'vict_age': '50',
#   'vict_descent': 'W',
#   'vict_sex': 'F'},
#  {'area_id': '03',
#   'area_name': 'Southwest',
#   'crm_cd': '230',
#   'crm_cd_1': '230',
#   'crm_cd_desc': 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#   'cross_street': 'MARTIN LUTHER KING           BL',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180325559',
#   'location': 'NORMANDIE                    AV',
#   'location_1': {'coordinates': [-118.3002, 34.0109], 'type': 'Point'},
#   'mocodes': '1822 0416 1202 0445 2021 0202',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '0376',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2115',
#   'vict_age': '62',
#   'vict_descent': 'H',
#   'vict_sex': 'M',
#   'weapon_desc': 'STICK',
#   'weapon_used_cd': '308'},
#  {'area_id': '04',
#   'area_name': 'Hollenbeck',
#   'crm_cd': '210',
#   'crm_cd_1': '210',
#   'crm_cd_desc': 'ROBBERY',
#   'cross_street': 'FICKETT',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180417366',
#   'location': 'CESAR E CHAVEZ',
#   'location_1': {'coordinates': [-118.2053, 34.0457], 'type': 'Point'},
#   'mocodes': '0334 0443',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '0457',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1830',
#   'vict_age': '31',
#   'vict_descent': 'H',
#   'vict_sex': 'M',
#   'weapon_desc': 'SIMULATED GUN',
#   'weapon_used_cd': '113'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '440',
#   'crm_cd_1': '440',
#   'crm_cd_2': '998',
#   'crm_cd_desc': 'THEFT PLAIN - PETTY ($950 & UNDER)',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180128307',
#   'location': '400 S  BROADWAY',
#   'location_1': {'coordinates': [-118.2494, 34.0495], 'type': 'Point'},
#   'mocodes': '0344 2004 1402',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '0143',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1927',
#   'vict_age': '34',
#   'vict_descent': 'B',
#   'vict_sex': 'M'},
#  {'area_id': '02',
#   'area_name': 'Rampart',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180222913',
#   'location': '900 N  MARIPOSA                     AV',
#   'location_1': {'coordinates': [-118.299, 34.0869], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0201',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1930',
#   'vict_age': '17'},
#  {'area_id': '06',
#   'area_name': 'Hollywood',
#   'crm_cd': '648',
#   'crm_cd_1': '648',
#   'crm_cd_desc': 'ARSON',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180623966',
#   'location': '8000    FLORAL                       AV',
#   'location_1': {'coordinates': [-118.3634, 34.1026], 'type': 'Point'},
#   'mocodes': '1501',
#   'premis_cd': '116',
#   'premis_desc': 'OTHER/OUTSIDE',
#   'rpt_dist_no': '0622',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0653',
#   'vict_descent': 'W',
#   'vict_sex': 'M'},
#  {'area_id': '06',
#   'area_name': 'Hollywood',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180623970',
#   'location': '6200    FOUNTAIN                     AV',
#   'location_1': {'coordinates': [-118.3245, 34.0944], 'type': 'Point'},
#   'mocodes': '0400 0416 2004',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '0666',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2300',
#   'vict_age': '17',
#   'vict_descent': 'W',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128333',
#   'location': '600 W  7TH                          ST',
#   'location_1': {'coordinates': [-118.2566, 34.0473], 'type': 'Point'},
#   'mocodes': '0400',
#   'premis_cd': '403',
#   'premis_desc': 'DRUG STORE',
#   'rpt_dist_no': '0162',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1900',
#   'vict_age': '24',
#   'vict_descent': 'B',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180518677',
#   'location': '500 N  CENTRE                       ST',
#   'location_1': {'coordinates': [-118.2835, 33.7469], 'type': 'Point'},
#   'premis_cd': '103',
#   'premis_desc': 'ALLEY',
#   'rpt_dist_no': '0558',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1830',
#   'vict_age': '17'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '210',
#   'crm_cd_1': '210',
#   'crm_cd_desc': 'ROBBERY',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128294',
#   'location': '800    WALL                         ST',
#   'location_1': {'coordinates': [-118.2504, 34.0401], 'type': 'Point'},
#   'mocodes': '0305 0444 0429 0355 0344',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '0176',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1440',
#   'vict_age': '54',
#   'vict_descent': 'O',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '07',
#   'area_name': 'Wilshire',
#   'crm_cd': '330',
#   'crm_cd_1': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'cross_street': '5TH                          AV',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180719800',
#   'location': 'COUNTRY CLUB                 DR',
#   'location_1': {'coordinates': [-118.3206, 34.0514], 'type': 'Point'},
#   'mocodes': '0344 0358 0385 1609',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0759',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0230',
#   'vict_age': '19',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '442',
#   'crm_cd_1': '442',
#   'crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128309',
#   'location': '700 W  7TH                          ST',
#   'location_1': {'coordinates': [-118.2577, 34.048], 'type': 'Point'},
#   'mocodes': '0325',
#   'premis_cd': '404',
#   'premis_desc': 'DEPARTMENT STORE',
#   'rpt_dist_no': '0162',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2000',
#   'vict_age': '25',
#   'vict_descent': 'W',
#   'vict_sex': 'F'},
#  {'area_id': '06',
#   'area_name': 'Hollywood',
#   'crm_cd': '330',
#   'crm_cd_1': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180623988',
#   'location': '2100 W  LIVE OAK                     DR',
#   'location_1': {'coordinates': [-118.3093, 34.1093], 'type': 'Point'},
#   'mocodes': '0344 1307 1609 0329',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0629',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2000',
#   'vict_age': '28',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '210',
#   'crm_cd_1': '210',
#   'crm_cd_desc': 'ROBBERY',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128267',
#   'location': '400 W  5TH                          ST',
#   'location_1': {'coordinates': [-118.2531, 34.0519], 'type': 'Point'},
#   'mocodes': '0344 0334',
#   'premis_cd': '252',
#   'premis_desc': "COFFEE SHOP (STARBUCKS, COFFEE BEAN, PEET'S, ETC.)",
#   'rpt_dist_no': '0142',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0950',
#   'vict_age': '32',
#   'vict_descent': 'W',
#   'vict_sex': 'M',
#   'weapon_desc': 'OTHER KNIFE',
#   'weapon_used_cd': '207'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'cross_street': 'OPP                          ST',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180518704',
#   'location': 'AVALON',
#   'location_1': {'coordinates': [-118.262, 33.7829], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0529',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1800',
#   'vict_age': '17'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '761',
#   'crm_cd_1': '761',
#   'crm_cd_desc': 'BRANDISH WEAPON',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128295',
#   'location': '900 N  BEAUDRY                      AV',
#   'location_1': {'coordinates': [-118.2468, 34.0674], 'type': 'Point'},
#   'mocodes': '0917 0603 0913 0334',
#   'premis_cd': '119',
#   'premis_desc': 'PORCH, RESIDENTIAL',
#   'rpt_dist_no': '0101',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1420',
#   'vict_age': '61',
#   'vict_descent': 'H',
#   'vict_sex': 'M',
#   'weapon_desc': 'MACHETE',
#   'weapon_used_cd': '215'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '956',
#   'crm_cd_1': '956',
#   'crm_cd_desc': 'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128293',
#   'location': '2000 E  7TH                          ST',
#   'location_1': {'coordinates': [-118.2335, 34.0387], 'type': 'Point'},
#   'mocodes': '0917 1803 0319 1906',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'rpt_dist_no': '0159',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0255',
#   'vict_age': '30',
#   'vict_descent': 'W',
#   'vict_sex': 'M',
#   'weapon_desc': 'UNKNOWN WEAPON/OTHER WEAPON',
#   'weapon_used_cd': '500'},
#  {'area_id': '07',
#   'area_name': 'Wilshire',
#   'crm_cd': '442',
#   'crm_cd_1': '442',
#   'crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180719806',
#   'location': '6300 W  3RD                          ST',
#   'location_1': {'coordinates': [-118.359, 34.0712], 'type': 'Point'},
#   'mocodes': '0325 0104',
#   'premis_cd': '402',
#   'premis_desc': 'MARKET',
#   'rpt_dist_no': '0734',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1726',
#   'vict_descent': 'O',
#   'vict_sex': 'M'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_2': '998',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'cross_street': 'GRAND                        AV',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128256',
#   'location': '7TH                          ST',
#   'location_1': {'coordinates': [-118.2566, 34.0473], 'type': 'Point'},
#   'mocodes': '1218 1402 0907',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0152',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0945',
#   'vict_age': '26',
#   'vict_descent': 'H',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '626',
#   'crm_cd_1': '626',
#   'crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180518684',
#   'location': '1100 S  BEACON                       ST',
#   'location_1': {'coordinates': [-118.2842, 33.7347], 'type': 'Point'},
#   'mocodes': '0448 0408 2000',
#   'premis_cd': '710',
#   'premis_desc': 'OTHER PREMISE',
#   'rpt_dist_no': '0566',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2045',
#   'vict_age': '48',
#   'vict_descent': 'B',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'cross_street': 'ALAMEDA                      ST',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128315',
#   'location': '7TH                          ST',
#   'location_1': {'coordinates': [-118.2386, 34.035], 'type': 'Point'},
#   'mocodes': '0448 0337 2004 0400',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0159',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2230',
#   'vict_age': '22',
#   'vict_descent': 'W',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '06',
#   'area_name': 'Hollywood',
#   'crm_cd': '330',
#   'crm_cd_1': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180623985',
#   'location': '1300 N  ORANGE GROVE                 AV',
#   'location_1': {'coordinates': [-118.3603, 34.0945], 'type': 'Point'},
#   'mocodes': '0344 1607 0329',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0642',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1045',
#   'vict_age': '35',
#   'vict_descent': 'A',
#   'vict_sex': 'M'},
#  {'area_id': '04',
#   'area_name': 'Hollenbeck',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180417381',
#   'location': '2300    HIGHBURY                     AV',
#   'location_1': {'coordinates': [-118.1624, 34.072], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0439',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1700',
#   'vict_age': '17'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '442',
#   'crm_cd_1': '442',
#   'crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128303',
#   'location': '700 W  7TH                          ST',
#   'location_1': {'coordinates': [-118.2577, 34.048], 'type': 'Point'},
#   'mocodes': '0344 2004',
#   'premis_cd': '203',
#   'premis_desc': 'OTHER BUSINESS',
#   'rpt_dist_no': '0162',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1310',
#   'vict_age': '24',
#   'vict_descent': 'H',
#   'vict_sex': 'F'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '420',
#   'crm_cd_1': '420',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180518665',
#   'location': '1700 N  GAFFEY                       ST',
#   'location_1': {'coordinates': [-118.2928, 33.7601], 'type': 'Point'},
#   'mocodes': '0344 1300',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'rpt_dist_no': '0521',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0645',
#   'vict_age': '19',
#   'vict_descent': 'A',
#   'vict_sex': 'M'},
#  {'area_id': '07',
#   'area_name': 'Wilshire',
#   'crm_cd': '341',
#   'crm_cd_1': '341',
#   'crm_cd_desc': 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180719816',
#   'location': '8400    BEVERLY                      BL',
#   'location_1': {'coordinates': [-118.3695, 34.0782], 'type': 'Point'},
#   'mocodes': '0325 0104 0329',
#   'premis_cd': '248',
#   'premis_desc': 'CELL PHONE STORE',
#   'rpt_dist_no': '0711',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2010',
#   'vict_descent': 'O',
#   'vict_sex': 'M'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180518641',
#   'location': '700 W  28TH                         ST',
#   'location_1': {'coordinates': [-118.2942, 33.7189], 'type': 'Point'},
#   'premis_cd': '104',
#   'premis_desc': 'DRIVEWAY',
#   'rpt_dist_no': '0584',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0355',
#   'vict_age': '17'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '210',
#   'crm_cd_1': '210',
#   'crm_cd_desc': 'ROBBERY',
#   'cross_street': 'FIGUEROA',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128243',
#   'location': '7TH',
#   'location_1': {'coordinates': [-118.2599, 34.0494], 'type': 'Point'},
#   'mocodes': '0344 0416',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '0151',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0200',
#   'vict_age': '36',
#   'vict_descent': 'O',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'cross_street': 'MESA                         ST',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '180518699',
#   'location': '11TH                         ST',
#   'location_1': {'coordinates': [-118.2857, 33.7342], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0566',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2100',
#   'vict_age': '17'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '946',
#   'crm_cd_1': '946',
#   'crm_cd_desc': 'OTHER MISCELLANEOUS CRIME',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180518687',
#   'location': '1000    NEPTUNE                      AV',
#   'location_1': {'coordinates': [-118.2691, 33.7826], 'type': 'Point'},
#   'mocodes': '0913 1813 2000',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '0532',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2245',
#   'vict_age': '31',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '210',
#   'crm_cd_1': '210',
#   'crm_cd_desc': 'ROBBERY',
#   'cross_street': 'BROADWAY',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180101143',
#   'location': '4TH',
#   'location_1': {'coordinates': [-118.2494, 34.0495], 'type': 'Point'},
#   'mocodes': '0344 0416 0417',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '0134',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0210',
#   'vict_age': '56',
#   'vict_descent': 'H',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128304',
#   'location': '400 S  SPRING                       ST',
#   'location_1': {'coordinates': [-118.25, 34.0488], 'type': 'Point'},
#   'mocodes': '0444',
#   'premis_cd': '203',
#   'premis_desc': 'OTHER BUSINESS',
#   'rpt_dist_no': '0143',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1320',
#   'vict_age': '57',
#   'vict_descent': 'B',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '05',
#   'area_name': 'Harbor',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'cross_street': 'EUBANK',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180518667',
#   'location': 'C',
#   'location_1': {'coordinates': [-118.2541, 33.7732], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0529',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1000',
#   'vict_age': '17'},
#  {'area_id': '03',
#   'area_name': 'Southwest',
#   'crm_cd': '210',
#   'crm_cd_1': '210',
#   'crm_cd_desc': 'ROBBERY',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180325557',
#   'location': '4000    CRENSHAW                     BL',
#   'location_1': {'coordinates': [-118.3351, 34.0124], 'type': 'Point'},
#   'mocodes': '0104 0325 1822 0945 0444 1816 0906 2004',
#   'premis_cd': '404',
#   'premis_desc': 'DEPARTMENT STORE',
#   'rpt_dist_no': '0363',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1500',
#   'vict_age': '17',
#   'vict_descent': 'X',
#   'vict_sex': 'X',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180128327',
#   'location': '600 W  7TH                          ST',
#   'location_1': {'coordinates': [-118.2566, 34.0473], 'type': 'Point'},
#   'mocodes': '0416',
#   'premis_cd': '406',
#   'premis_desc': 'OTHER STORE',
#   'rpt_dist_no': '0162',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1900',
#   'vict_age': '59',
#   'vict_descent': 'B',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '341',
#   'crm_cd_1': '341',
#   'crm_cd_desc': 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#   'cross_street': 'SHIRLEY',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '181018743',
#   'location': 'WELLS',
#   'location_1': {'coordinates': [-118.5577, 34.1642], 'type': 'Point'},
#   'mocodes': '0344',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '1091',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2120',
#   'vict_age': '44',
#   'vict_descent': 'O',
#   'vict_sex': 'M'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '442',
#   'crm_cd_1': '442',
#   'crm_cd_2': '998',
#   'crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180920808',
#   'location': '14000    RIVERSIDE                    DR',
#   'location_1': {'coordinates': [-118.438, 34.1576], 'type': 'Point'},
#   'mocodes': '0325 1402',
#   'premis_cd': '404',
#   'premis_desc': 'DEPARTMENT STORE',
#   'rpt_dist_no': '0964',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1530',
#   'vict_descent': 'X',
#   'vict_sex': 'X'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '480',
#   'crm_cd_1': '480',
#   'crm_cd_desc': 'BIKE - STOLEN',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '181018721',
#   'location': '16300    VENTURA                      BL',
#   'location_1': {'coordinates': [-118.4917, 34.1613], 'type': 'Point'},
#   'mocodes': '0344',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'rpt_dist_no': '1078',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0800',
#   'vict_age': '49',
#   'vict_descent': 'B',
#   'vict_sex': 'M'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '441',
#   'crm_cd_1': '441',
#   'crm_cd_2': '998',
#   'crm_cd_desc': 'THEFT PLAIN - ATTEMPT',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180819360',
#   'location': '10800    SANTA MONICA                 BL',
#   'location_1': {'coordinates': [-118.4345, 34.0507], 'type': 'Point'},
#   'mocodes': '1822 0216 1402',
#   'premis_cd': '301',
#   'premis_desc': 'GAS STATION',
#   'rpt_dist_no': '0855',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0330',
#   'vict_descent': 'X',
#   'vict_sex': 'X'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '420',
#   'crm_cd_1': '420',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180920789',
#   'location': '14700    VICTORY                      BL',
#   'location_1': {'coordinates': [-118.4574, 34.1903], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0923',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0800',
#   'vict_age': '17'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '354',
#   'crm_cd_1': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180920798',
#   'location': '4400 N  SEPULVEDA                    BL',
#   'location_1': {'coordinates': [-118.4674, 34.15], 'type': 'Point'},
#   'mocodes': '0928 1822',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '0981',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0600',
#   'vict_age': '24',
#   'vict_descent': 'O',
#   'vict_sex': 'F'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '956',
#   'crm_cd_1': '956',
#   'crm_cd_desc': 'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '181018718',
#   'location': '5800    YOLANDA                      AV',
#   'location_1': {'coordinates': [-118.5407, 34.1757], 'type': 'Point'},
#   'mocodes': '0361',
#   'premis_cd': '507',
#   'premis_desc': 'CONDOMINIUM/TOWNHOUSE',
#   'rpt_dist_no': '1043',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1213',
#   'vict_age': '39',
#   'vict_descent': 'O',
#   'vict_sex': 'M',
#   'weapon_desc': 'VERBAL THREAT',
#   'weapon_used_cd': '511'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '341',
#   'crm_cd_1': '341',
#   'crm_cd_desc': 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '181018727',
#   'location': '17100    VICTORY                      BL',
#   'location_1': {'coordinates': [-118.5053, 34.1866], 'type': 'Point'},
#   'mocodes': '0344',
#   'premis_cd': '721',
#   'premis_desc': 'HIGH SCHOOL',
#   'rpt_dist_no': '1037',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2025',
#   'vict_age': '17',
#   'vict_descent': 'W',
#   'vict_sex': 'F'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '354',
#   'crm_cd_1': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '180920799',
#   'location': '4400 N  SEPULVEDA                    BL',
#   'location_1': {'coordinates': [-118.4674, 34.15], 'type': 'Point'},
#   'mocodes': '0928 1822',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '0981',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0600',
#   'vict_age': '33',
#   'vict_descent': 'W',
#   'vict_sex': 'M'},
#  {'area_id': '11',
#   'area_name': 'Northeast',
#   'crm_cd': '310',
#   'crm_cd_1': '310',
#   'crm_cd_desc': 'BURGLARY',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '181119582',
#   'location': '100 N  AVENUE 50',
#   'location_1': {'coordinates': [-118.2023, 34.1052], 'type': 'Point'},
#   'mocodes': '1608 0344',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'rpt_dist_no': '1148',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0130',
#   'vict_age': '44',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '11',
#   'area_name': 'Northeast',
#   'crm_cd': '420',
#   'crm_cd_1': '420',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181119589',
#   'location': '300    MUSEUM                       DR',
#   'location_1': {'coordinates': [-118.2072, 34.1], 'type': 'Point'},
#   'mocodes': '0344',
#   'premis_cd': '104',
#   'premis_desc': 'DRIVEWAY',
#   'rpt_dist_no': '1148',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1615',
#   'vict_age': '31',
#   'vict_descent': 'W',
#   'vict_sex': 'F'},
#  {'area_id': '11',
#   'area_name': 'Northeast',
#   'crm_cd': '440',
#   'crm_cd_1': '440',
#   'crm_cd_desc': 'THEFT PLAIN - PETTY ($950 & UNDER)',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '181119580',
#   'location': '3000    PETITE                       CT',
#   'location_1': {'coordinates': [-118.2582, 34.1098], 'type': 'Point'},
#   'mocodes': '0394',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'rpt_dist_no': '1133',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1600',
#   'vict_age': '38',
#   'vict_descent': 'H',
#   'vict_sex': 'F'},
#  {'area_id': '13',
#   'area_name': 'Newton',
#   'crm_cd': '420',
#   'crm_cd_1': '420',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#   'cross_street': 'MCKINLEY                     AV',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-17T00:00:00.000',
#   'dr_no': '181322916',
#   'location': '42ND',
#   'location_1': {'coordinates': [-118.2609, 34.0067], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '1344',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1830',
#   'vict_age': '17'},
#  {'area_id': '16',
#   'area_name': 'Foothill',
#   'crm_cd': '956',
#   'crm_cd_1': '956',
#   'crm_cd_desc': 'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
#   'date_occ': '2018-11-16T00:00:00.000',
#   'date_rptd': '2018-11-16T00:00:00.000',
#   'dr_no': '181616634',
#   'location': '12300    BRANFORD                     ST',
#   'location_1': {'coordinates': [-118.3994, 34.257], 'type': 'Point'},
#   'mocodes': '0422 0421',
#   'premis_cd': '203',
#   'premis_desc': 'OTHER BUSINESS',
#   'rpt_dist_no': '1654',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1500',
# ...
#   'mocodes': '0416 0444 0447 0913',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0356',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1330',
#   'vict_age': '51',
#   'vict_descent': 'H',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '01',
#   'area_name': 'Central',
#   'crm_cd': '900',
#   'crm_cd_1': '900',
#   'crm_cd_desc': 'VIOLATION OF COURT ORDER',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180128075',
#   'location': '1100 S  LOS ANGELES                  ST',
#   'location_1': {'coordinates': [-118.2571, 34.0384], 'type': 'Point'},
#   'mocodes': '1501',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0185',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1430',
#   'vict_age': '37',
#   'vict_descent': 'H',
#   'vict_sex': 'F'},
#  {'area_id': '06',
#   'area_name': 'Hollywood',
#   'crm_cd': '230',
#   'crm_cd_1': '230',
#   'crm_cd_desc': 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180623832',
#   'location': '1700 N  HIGHLAND                     AV',
#   'location_1': {'coordinates': [-118.3387, 34.1016], 'type': 'Point'},
#   'mocodes': '0400 0447',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0636',
#   'status': 'AA',
#   'status_desc': 'Adult Arrest',
#   'time_occ': '2000',
#   'vict_age': '22',
#   'vict_descent': 'W',
#   'vict_sex': 'M',
#   'weapon_desc': 'BOTTLE',
#   'weapon_used_cd': '212'},
#  {'area_id': '06',
#   'area_name': 'Hollywood',
#   'crm_cd': '888',
#   'crm_cd_1': '888',
#   'crm_cd_desc': 'TRESPASSING',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180623749',
#   'location': '700 N  SAINT ANDREWS                PL',
#   'location_1': {'coordinates': [-118.3114, 34.0835], 'type': 'Point'},
#   'mocodes': '1501',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'rpt_dist_no': '0677',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0030',
#   'vict_age': '50',
#   'vict_descent': 'H',
#   'vict_sex': 'F'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '624',
#   'crm_cd_1': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'cross_street': 'KINROSS',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180819271',
#   'location': 'GAYLEY                       AV',
#   'location_1': {'coordinates': [-118.4465, 34.0602], 'type': 'Point'},
#   'mocodes': '0416 1822',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '0817',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1200',
#   'vict_age': '35',
#   'vict_descent': 'B',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '888',
#   'crm_cd_1': '888',
#   'crm_cd_desc': 'TRESPASSING',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '180920679',
#   'location': '6600    VAN NUYS                     BL',
#   'location_1': {'coordinates': [-118.4574, 34.1903], 'type': 'Point'},
#   'mocodes': '0325',
#   'premis_cd': '402',
#   'premis_desc': 'MARKET',
#   'rpt_dist_no': '0923',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1715',
#   'vict_descent': 'X',
#   'vict_sex': 'X'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '330',
#   'crm_cd_1': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180819246',
#   'location': '10200    SANTA MONICA                 BL',
#   'location_1': {'coordinates': [-118.4193, 34.0605], 'type': 'Point'},
#   'mocodes': '1221 0344 1302 1822 0352',
#   'premis_cd': '707',
#   'premis_desc': 'GARAGE/CARPORT',
#   'rpt_dist_no': '0839',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1210',
#   'vict_age': '50',
#   'vict_descent': 'O',
#   'vict_sex': 'M'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '440',
#   'crm_cd_1': '440',
#   'crm_cd_desc': 'THEFT PLAIN - PETTY ($950 & UNDER)',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '181018589',
#   'location': '19500    ELKWOOD                      ST',
#   'location_1': {'coordinates': [-118.5579, 34.2128], 'type': 'Point'},
#   'mocodes': '0344',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '1001',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1700',
#   'vict_age': '48',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '330',
#   'crm_cd_1': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '181018597',
#   'location': '18500    BURBANK                      BL',
#   'location_1': {'coordinates': [-118.536, 34.1724], 'type': 'Point'},
#   'mocodes': '0344',
#   'premis_cd': '707',
#   'premis_desc': 'GARAGE/CARPORT',
#   'rpt_dist_no': '1063',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2300',
#   'vict_age': '34',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '421',
#   'crm_cd_1': '421',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - ATTEMPT',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180901001',
#   'location': '5300 N  SEPULVEDA                    BL',
#   'location_1': {'coordinates': [-118.4662, 34.1667], 'type': 'Point'},
#   'mocodes': '1300 1402',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0952',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0325',
#   'vict_age': '38',
#   'vict_descent': 'B',
#   'vict_sex': 'M'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180819218',
#   'location': '10500    AYRES                        AV',
#   'location_1': {'coordinates': [-118.4184, 34.0444], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0885',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1025',
#   'vict_age': '17'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '341',
#   'crm_cd_1': '341',
#   'crm_cd_desc': 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '180819289',
#   'location': '2500    ROSCOMARE                    RD',
#   'location_1': {'coordinates': [-118.4698, 34.1016], 'type': 'Point'},
#   'mocodes': '0344 0346',
#   'premis_cd': '104',
#   'premis_desc': 'DRIVEWAY',
#   'rpt_dist_no': '0805',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1600',
#   'vict_descent': 'X',
#   'vict_sex': 'X'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '330',
#   'crm_cd_1': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180819236',
#   'location': '11700    WILSHIRE                     BL',
#   'location_1': {'coordinates': [-118.4643, 34.0511], 'type': 'Point'},
#   'mocodes': '1202 0344 0346 1609 1307 0358',
#   'premis_cd': '707',
#   'premis_desc': 'GARAGE/CARPORT',
#   'rpt_dist_no': '0832',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1150',
#   'vict_age': '60',
#   'vict_descent': 'W',
#   'vict_sex': 'M'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '442',
#   'crm_cd_1': '442',
#   'crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180819247',
#   'location': '10500 W  PICO                         BL',
#   'location_1': {'coordinates': [-118.4206, 34.0473], 'type': 'Point'},
#   'mocodes': '0352 0104 0202',
#   'premis_cd': '248',
#   'premis_desc': 'CELL PHONE STORE',
#   'rpt_dist_no': '0847',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1840',
#   'vict_descent': 'X',
#   'vict_sex': 'X'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '812',
#   'crm_cd_1': '624',
#   'crm_cd_2': '812',
#   'crm_cd_desc': 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180920669',
#   'location': '15200    SHERMAN                      WY',
#   'location_1': {'coordinates': [-118.4599, 34.2084], 'type': 'Point'},
#   'mocodes': '0400 1601 1251 1258 0444 1309',
#   'premis_cd': '138',
#   'premis_desc': 'STAIRWELL*',
#   'rpt_dist_no': '0904',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1920',
#   'vict_age': '13',
#   'vict_descent': 'H',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '354',
#   'crm_cd_1': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '180920676',
#   'location': '15000    MOORPARK                     ST',
#   'location_1': {'coordinates': [-118.4596, 34.1537], 'type': 'Point'},
#   'mocodes': '0930 1822',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '0971',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0700',
#   'vict_age': '32',
#   'vict_descent': 'O',
#   'vict_sex': 'F'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '330',
#   'crm_cd_1': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-15T00:00:00.000',
#   'dr_no': '180920727',
#   'location': '14600    DELANO                       ST',
#   'location_1': {'coordinates': [-118.4509, 34.1827], 'type': 'Point'},
#   'mocodes': '0344 1302',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'rpt_dist_no': '0933',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2000',
#   'vict_age': '28',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '888',
#   'crm_cd_1': '888',
#   'crm_cd_desc': 'TRESPASSING',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180819241',
#   'location': '1400    DAWNRIDGE                    DR',
#   'location_1': {'coordinates': [-118.4188, 34.0958], 'type': 'Point'},
#   'mocodes': '1202',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '0808',
#   'status': 'AA',
#   'status_desc': 'Adult Arrest',
#   'time_occ': '0745',
#   'vict_age': '62',
#   'vict_descent': 'A',
#   'vict_sex': 'M'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '626',
#   'crm_cd_1': '626',
#   'crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180819251',
#   'location': '11900 W  SUNSET                       BL',
#   'location_1': {'coordinates': [-118.4768, 34.0738], 'type': 'Point'},
#   'mocodes': '2000 0416 1814',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'rpt_dist_no': '0813',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1830',
#   'vict_age': '45',
#   'vict_descent': 'W',
#   'vict_sex': 'M',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '888',
#   'crm_cd_1': '888',
#   'crm_cd_desc': 'TRESPASSING',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180920647',
#   'location': '14400    VALLEY VISTA                 BL',
#   'location_1': {'coordinates': [-118.4424, 34.15], 'type': 'Point'},
#   'mocodes': '1501',
#   'premis_cd': '121',
#   'premis_desc': 'YARD (RESIDENTIAL/BUSINESS)',
#   'rpt_dist_no': '0985',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1030',
#   'vict_age': '34',
#   'vict_descent': 'H',
#   'vict_sex': 'M'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '510',
#   'crm_cd_1': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '180920691',
#   'location': '7100    LENNOX                       AV',
#   'location_1': {'coordinates': [-118.4455, 34.1996], 'type': 'Point'},
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'rpt_dist_no': '0915',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2100',
#   'vict_age': '17'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '330',
#   'crm_cd_1': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '180920701',
#   'location': '14900    VANOWEN                      ST',
#   'location_1': {'coordinates': [-118.4574, 34.1976], 'type': 'Point'},
#   'mocodes': '0344 1251',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0914',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2330',
#   'vict_age': '25',
#   'vict_descent': 'H',
#   'vict_sex': 'F'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '626',
#   'crm_cd_1': '626',
#   'crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '180920670',
#   'location': '7000    LENNOX                       AV',
#   'location_1': {'coordinates': [-118.4455, 34.1976], 'type': 'Point'},
#   'mocodes': '2000 0400 1601 0416 1814',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'rpt_dist_no': '0915',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '2300',
#   'vict_age': '19',
#   'vict_descent': 'H',
#   'vict_sex': 'F',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'weapon_used_cd': '400'},
#  {'area_id': '09',
#   'area_name': 'Van Nuys',
#   'crm_cd': '420',
#   'crm_cd_1': '420',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '180920715',
#   'location': '14800    ERWIN                        ST',
#   'location_1': {'coordinates': [-118.4553, 34.1837], 'type': 'Point'},
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'rpt_dist_no': '0933',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1600',
#   'vict_age': '17'},
#  {'area_id': '10',
#   'area_name': 'West Valley',
#   'crm_cd': '310',
#   'crm_cd_1': '310',
#   'crm_cd_desc': 'BURGLARY',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-14T00:00:00.000',
#   'dr_no': '181018618',
#   'location': '5100    GAYNOR                       AV',
#   'location_1': {'coordinates': [-118.4804, 34.1629], 'type': 'Point'},
#   'mocodes': '1609 0321',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'rpt_dist_no': '1079',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '1730',
#   'vict_descent': 'O',
#   'vict_sex': 'F'},
#  {'area_id': '08',
#   'area_name': 'West LA',
#   'crm_cd': '310',
#   'crm_cd_1': '310',
#   'crm_cd_desc': 'BURGLARY',
#   'date_occ': '2018-11-13T00:00:00.000',
#   'date_rptd': '2018-11-13T00:00:00.000',
#   'dr_no': '180819244',
#   'location': '1900    BELOIT                       AV',
#   'location_1': {'coordinates': [-118.444, 34.0431], 'type': 'Point'},
#   'mocodes': '0344 1822 1607 0321',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'rpt_dist_no': '0882',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'time_occ': '0945',
#   'vict_age': '27',
#   'vict_descent': 'O',
#   'vict_sex': 'M'}]

# %%
# Get crime data for rolling 7 days of recent crimes

# Create a Pandas DataFrame with the results
crime_data = pd.DataFrame(incidents).set_index(['dr_no'])
crime_data = crime_data.sort_values(by='date_occ', ascending=False)

crime_data.dtypes
# Out:
# area_id           object
# area_name         object
# crm_cd            object
# crm_cd_1          object
# crm_cd_2          object
# crm_cd_3          object
# crm_cd_desc       object
# cross_street      object
# date_occ          object
# date_rptd         object
# location          object
# location_1        object
# mocodes           object
# premis_cd         object
# premis_desc       object
# rpt_dist_no       object
# status            object
# status_desc       object
# time_occ          object
# vict_age          object
# vict_descent      object
# vict_sex          object
# weapon_desc       object
# weapon_used_cd    object
# dtype: object

# %%
# Set column datatypes and drop some columns
crime_data['area_id'] = crime_data['area_id'].apply(pd.to_numeric)
crime_data['crm_cd'] = crime_data['crm_cd'].apply(pd.to_numeric)
crime_data['crm_cd_1'] = crime_data['crm_cd_1'].apply(pd.to_numeric)
crime_data['crm_cd_2'] = crime_data['crm_cd_2'].apply(pd.to_numeric)
crime_data['crm_cd_3'] = crime_data['crm_cd_3'].apply(pd.to_numeric)
crime_data['date_occ'] = pd.to_datetime(crime_data['date_occ'], infer_datetime_format=True)
crime_data['date_rptd'] = pd.to_datetime(crime_data['date_rptd'], infer_datetime_format=True)
crime_data[['loc_type','coordinates']] = crime_data['location_1'].apply(pd.Series)
crime_data[['longitude','latitude']] = crime_data['coordinates'].apply(pd.Series)
crime_data = crime_data.drop(columns=['location_1'])
crime_data = crime_data.drop(columns=['coordinates'])
crime_data['premis_cd'] = crime_data['premis_cd'].apply(pd.to_numeric)
crime_data['rpt_dist_no'] = crime_data['rpt_dist_no'].apply(pd.to_numeric)
crime_data['hour_occ'] = crime_data['time_occ'].str[:2].apply(pd.to_numeric)
crime_data['minute_occ'] = crime_data['time_occ'].str[2:].apply(pd.to_numeric)
crime_data = crime_data.drop(columns=['time_occ'])
crime_data['vict_age'] = crime_data['vict_age'].apply(pd.to_numeric)
crime_data['weapon_used_cd'] = crime_data['weapon_used_cd'].apply(pd.to_numeric)

crime_data.dtypes
# Out:
# area_id                    int64
# area_name                 object
# crm_cd                     int64
# crm_cd_1                   int64
# crm_cd_2                 float64
# crm_cd_3                 float64
# crm_cd_desc               object
# cross_street              object
# date_occ          datetime64[ns]
# date_rptd         datetime64[ns]
# location                  object
# mocodes                   object
# premis_cd                  int64
# premis_desc               object
# rpt_dist_no                int64
# status                    object
# status_desc               object
# vict_age                 float64
# vict_descent              object
# vict_sex                  object
# weapon_desc               object
# weapon_used_cd           float64
# loc_type                  object
# longitude                float64
# latitude                 float64
# hour_occ                   int64
# minute_occ                 int64
# dtype: object

# %%
crime_data.head()
# Out:
#            area_id  area_name  crm_cd  crm_cd_1  crm_cd_2  crm_cd_3  \
# dr_no
# 180623987        6  Hollywood     330       330       NaN       NaN
# 181322936       13     Newton     648       648       NaN       NaN
# 180518688        5     Harbor     626       626       NaN       NaN
# 181322911       13     Newton     230       230       NaN       NaN
# 181616637       16   Foothill     888       888       NaN       NaN
#
#                                               crm_cd_desc cross_street  \
# dr_no
# 180623987                           BURGLARY FROM VEHICLE          NaN
# 181322936                                           ARSON          NaN
# 180518688               INTIMATE PARTNER - SIMPLE ASSAULT          NaN
# 181322911  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT          NaN
# 181616637                                     TRESPASSING          NaN
#
#             date_occ  date_rptd    ...     vict_age vict_descent  vict_sex  \
# dr_no                              ...
# 180623987 2018-11-17 2018-11-17    ...         22.0            O         M
# 181322936 2018-11-17 2018-11-17    ...         34.0            B         M
# 180518688 2018-11-17 2018-11-17    ...         39.0            H         F
# 181322911 2018-11-17 2018-11-17    ...         24.0            H         M
# 181616637 2018-11-17 2018-11-17    ...         62.0            H         M
#
#                                               weapon_desc  weapon_used_cd  \
# dr_no
# 180623987                                             NaN             NaN
# 181322936                                            FIRE           506.0
# 180518688  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)           400.0
# 181322911                     UNKNOWN WEAPON/OTHER WEAPON           500.0
# 181616637                                             NaN             NaN
#
#           loc_type longitude  latitude hour_occ minute_occ
# dr_no
# 180623987    Point -118.3295   34.1016        0         30
# 181322936    Point -118.2697   33.9981        0          1
# 180518688    Point -118.2879   33.7115        1         40
# 181322911    Point -118.2696   33.9988       21          0
# 181616637    Point -118.4249   34.2520        5          0
#
# [5 rows x 27 columns]

# %%
# Create sqlalchemy engine
from sqlalchemy import create_engine
# engine = create_engine('sqlite:///db/la_crime.db', echo=True)

conn = sqlite3.connect("db/la_crime.db")
c = conn.cursor()
c.execute('''DROP TABLE IF EXISTS new_la_crime;''')
c.execute('''CREATE TABLE new_la_crime
            (dr_no INTEGER PRIMARY KEY ASC,
             area_id INTEGER,
             area_name VARCHAR(64),
             crm_cd INTEGER,
             crm_cd_1 INTEGER,
             crm_cd_2 INTEGER,
             crm_cd_3 INTEGER,
             crm_cd_desc VARCHAR(64),
             cross_street VARCHAR(64),
             date_occ DATE,
             date_rptd DATE,
             location VARCHAR(64),
             longitude FLOAT,
             latitude FLOAT,
             mocodes TEXT,
             premis_cd INTEGER,
             premis_desc VARCHAR(64),
             rpt_dist_no INTEGER,
             status VARCHAR(2),
             status_desc VARCHAR(64),
             hour_occ INTEGER,
             minute_occ INTEGER,
             vict_age INTEGER,
             vict_descent VARCHAR(64),
             vict_sex VARCHAR(2),
             weapon_desc VARCHAR(64),
             weapon_used_cd INTEGER,
             loc_type VARCHAR(64))
             ''')
conn.commit()
conn.close()

# %%
# Create original table
engine = create_engine('sqlite:///db/la_crime.db')
crime_data.to_sql('new_la_crime', engine, if_exists='append', index=True, )
